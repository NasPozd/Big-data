# %%
import pandas as pd

# Загрузка данных
data = pd.read_csv("insurance.csv")
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
import pandas as pd

# Загрузка данных
data = pd.read_csv("insurance.csv")

# Просмотр статистики по данным
print(data.describe())
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
import matplotlib.pyplot as plt
import numpy as np

# Загрузка данных
data = pd.read_csv("insurance.csv")

# Построение гистограммы BMI
data['bmi'].hist()

# Настройка графика
plt.xlabel('BMI')
plt.ylabel('Количество')
plt.title('Гистограмма BMI')

# Отображение графика
plt.show()

# Построение гистограммы AGE
data['age'].hist()

# Настройка графика
plt.xlabel('Возраст')
plt.ylabel('Количество')
plt.title('Гистограмма возраста')

# Отображение графика
plt.show()

# Построение гистограммы CHILDREN
data['children'].hist()

# Настройка графика
plt.xlabel('Дети')
plt.ylabel('Количество')
plt.title('Гистограмма детей')

# Отображение графика
plt.show()

# Построение гистограммы CHARGES
data['charges'].hist()

# Настройка графика
plt.xlabel('Расходы')
plt.ylabel('Количество')
plt.title('Гистограмма расходов')

# Отображение графика
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных
data = pd.read_csv('insurance.csv')

# Меры центральной тенденции для индекса массы тела (bmi)
bmi_mean = data['bmi'].mean()
bmi_median = data['bmi'].median()
bmi_mode = data['bmi'].mode().values[0]

# Меры разброса для индекса массы тела (bmi)
bmi_min = data['bmi'].min()
bmi_max = data['bmi'].max()
bmi_std = data['bmi'].std()

# Меры центральной тенденции для расходов (charges)
charges_mean = data['charges'].mean()
charges_median = data['charges'].median()
charges_mode = data['charges'].mode().values[0]

# Меры разброса для расходов (charges)
charges_min = data['charges'].min()
charges_max = data['charges'].max()
charges_std = data['charges'].std()

# Вывод результатов в виде текста
print('Меры центральной тенденции для BMI:')
print('Среднее значение: ', bmi_mean)
print('Медиана: ', bmi_median)
print('Мода: ', bmi_mode)

print('\nМеры разброса для BMI:')
print('Минимальное значение: ', bmi_min)
print('Максимальное значение: ', bmi_max)
print('Стандартное отклонение: ', bmi_std)

print('\nМеры центральной тенденции для расходов:')
print('Среднее значение: ', charges_mean)
print('Медиана: ', charges_median)
print('Мода: ', charges_mode)

print('\nМеры разброса для расходов:')
print('Минимальное значение: ', charges_min)
print('Максимальное значение: ', charges_max)
print('Стандартное отклонение: ', charges_std)

# Гистограмма для индекса массы тела (bmi)
plt.hist(data['bmi'], bins=30, color='blue', alpha=0.7)
plt.axvline(bmi_mean, color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(bmi_median, color='green', linestyle='dashed', linewidth=2, label='Median')
plt.axvline(bmi_mode, color='purple', linestyle='dashed', linewidth=2, label='Mode')
plt.title('Гистограмма BMI')
plt.xlabel('BMI')
plt.ylabel('Частота')
plt.legend()
plt.show()

# Гистограмма для расходов (charges)
plt.hist(data['charges'], bins=30, color='orange', alpha=0.7)
plt.axvline(charges_mean, color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(charges_median, color='green', linestyle='dashed', linewidth=2, label='Median')
plt.axvline(charges_mode, color='purple', linestyle='dashed', linewidth=2, label='Mode')
plt.title('Гистограмма расходов')
plt.xlabel('Расходы')
plt.ylabel('Частота')
plt.legend()
plt.show()
# Out:
# Меры центральной тенденции для BMI:
# Среднее значение:  30.66339686098655
# Медиана:  30.4
# Мода:  32.3
#
# Меры разброса для BMI:
# Минимальное значение:  15.96
# Максимальное значение:  53.13
# Стандартное отклонение:  6.098186911679017
#
# Меры центральной тенденции для расходов:
# Среднее значение:  13270.422265141257
# Медиана:  9382.033
# Мода:  1639.5631
#
# Меры разброса для расходов:
# Минимальное значение:  1121.8739
# Максимальное значение:  63770.42801
# Стандартное отклонение:  12110.011236693994

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Загрузка данных из файла
data = pd.read_csv("insurance.csv")

# Построение box-plot для числового признака "age"
plt.figure(figsize=(10, 5))
sns.boxplot(data["age"], color="red")
plt.title("Возраст")
plt.show()

# Построение box-plot для числового признака "bmi"
plt.figure(figsize=(10, 5))
sns.boxplot(data["bmi"], color="violet")
plt.title("BMI")
plt.show()

# Построение box-plot для числового признака "children"
plt.figure(figsize=(10, 5))
sns.boxplot(data["children"], color="purple")
plt.title("Дети")
plt.show()

# Построение box-plot для числового признака "charges"
plt.figure(figsize=(10, 5))
sns.boxplot(data["charges"], color="lime")
plt.title("Расходы")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('insurance.csv')

#Создадим список, содержащий 300 выборок длиной по n элементов
bmi_samples = [data['bmi'].sample(25) for _ in range(300)]

#Вычислим среднее и стандартное отклонение для каждой выборки
means = [sample.mean() for sample in bmi_samples]
stds = [sample.std() for sample in bmi_samples]

#Выведем гистограммы для средних значений и стандартных отклонений
plt.hist(means, bins=30)
plt.xlabel('Среднее значение BMI')
plt.ylabel('Частота')
plt.title('Гистограмма средних значений BMI')
plt.show()

plt.hist(stds, bins=30)
plt.xlabel('Стандартное отклонение BMI')
plt.ylabel('Частота')
plt.title('Гистограмма стандартных отклонений BMI')
plt.show()

print('Среднее значение BMI:', np.mean(means))
print('Стандартное отклонение BMI:', np.std(stds))
# Out:
# Среднее значение BMI: 30.701088
# Стандартное отклонение BMI: 0.8468739429596279

# %%
import pandas as pd
import numpy as np
from scipy import stats

data = pd.read_csv("insurance.csv")

# Вычисление выборочного среднего и стандартного отклонения для charges и bmi
mean_charges = data["charges"].mean()
std_charges = data["charges"].std()

mean_bmi = data["bmi"].mean()
std_bmi = data["bmi"].std()

# Расчет доверительных интервалов для charges и bmi на уровне доверия 95%
n = len(data)
confidence_level = 0.95
Z = stats.norm.ppf(confidence_level) #критическое значение

charges_interval_95 = (mean_charges - Z * std_charges / np.sqrt(n), mean_charges + Z * std_charges / np.sqrt(n))
bmi_interval_95 = (mean_bmi - Z * std_bmi / np.sqrt(n), mean_bmi + Z * std_bmi / np.sqrt(n))

# Расчет доверительных интервалов для charges и bmi на уровне доверия 99%
confidence_level = 0.99
Z = stats.norm.ppf(confidence_level)

charges_interval_99 = (mean_charges - Z * std_charges / np.sqrt(n), mean_charges + Z * std_charges / np.sqrt(n))
bmi_interval_99 = (mean_bmi - Z * std_bmi / np.sqrt(n), mean_bmi + Z * std_bmi / np.sqrt(n))

print("Доверительный интервал для среднего значения charges (95% уровень доверия):", charges_interval_95)
print("Доверительный интервал для среднего значения bmi (95% уровень доверия):", bmi_interval_95)

print("Доверительный интервал для среднего значения charges (99% уровень доверия):", charges_interval_99)
print("Доверительный интервал для среднего значения bmi (99% уровень доверия):", bmi_interval_99)
# Out:
# Доверительный интервал для среднего значения charges (95% уровень доверия): (12725.864762144516, 13814.979768137997)
# Доверительный интервал для среднего значения bmi (95% уровень доверия): (30.389176352638128, 30.93761736933497)
# Доверительный интервал для среднего значения charges (99% уровень доверия): (12500.244196629856, 14040.600333652657)
# Доверительный интервал для среднего значения bmi (99% уровень доверия): (30.275561562962444, 31.051232159010652)

# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

data = pd.read_csv('insurance.csv')
bmi_data = data['bmi']
charges_data = data['charges']

# Проводим KS-тест для признака bmi
ks_statistic, p_value = stats.kstest(bmi_data, 'norm')
print("KS-тест для признака bmi:")
print("KS-статистика:", ks_statistic)
print("p-значение:", p_value)

# Строим Q-Q plot для признака bmi
stats.probplot(bmi_data, dist='norm', plot=plt)
plt.title('Q-Q plot для признака bmi')
plt.show()

# Проводим KS-тест для признака charges
ks_statistic, p_value = stats.kstest(charges_data, 'norm')
print("KS-тест для признака charges:")
print("KS-статистика:", ks_statistic)
print("p-значение:", p_value)

# Строим Q-Q plot для признака charges
stats.probplot(charges_data, dist='norm', plot=plt)
plt.title('Q-Q plot для признака charges')
plt.show()
# Out:
# KS-тест для признака bmi:
# KS-статистика: 1.0
# p-значение: 0.0
# KS-тест для признака charges:
# KS-статистика: 1.0
# p-значение: 0.0

# %%
import pandas as pd

# Загрузка данных
data = pd.read_csv("ECDCCases.csv")
# Out:
#                 day         month          year          cases        deaths  \
# count  61904.000000  61904.000000  61904.000000   61904.000000  61904.000000
# mean      15.629232      7.067104   2019.998918    1155.079026     26.053987
# std        8.841624      2.954816      0.032881    6779.010824    131.222948
# min        1.000000      1.000000   2019.000000   -8261.000000  -1918.000000
# 25%        8.000000      5.000000   2020.000000       0.000000      0.000000
# 50%       15.000000      7.000000   2020.000000      15.000000      0.000000
# 75%       23.000000     10.000000   2020.000000     273.000000      4.000000
# max       31.000000     12.000000   2020.000000  234633.000000   4928.000000
#
#         popData2019  \
# count  6.178100e+04
# mean   4.098628e+07
# std    1.531246e+08
# min    8.150000e+02
# 25%    1.293120e+06
# 50%    7.169456e+06
# 75%    2.851583e+07
# max    1.433784e+09
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as sts


data = pd.read_csv("ECDCCases.csv")
data.describe()

# Проверка наличия пропущенных значений
missing_values = data.isnull().sum()
total_missing = missing_values.sum()

# Вывод количества пропущенных значений в процентах
percent_missing = (total_missing / (data.shape[0] * data.shape[1])) * 100 

#shape - кортеж размеров массива
#Форма массива - кол-во элементов в каждом измерении
print(f"Процент пропущенных значений:({percent_missing}%)")

# Удаление двух признаков с наибольшим количеством пропущенных значений
data = data.dropna(axis=1, thresh=data.shape[0] - 2) 
#dropna для удаления пустых значений

# Обработка пропусков для оставшихся признаков
for column in data.columns:
    if data[column].dtype == "object":
        data[column] = data[column].fillna("other")
    else:
        median_value = data[column].median()
        data[column] = data[column].fillna(median_value)
        
# Проверка отсутствия пропусков в данных
missing_values = data.isnull().sum().sum()
print(f"Текущее количество пропущенных значений: {missing_values}")
# Out:
# Процент пропущенных значений:(0.4576979408977342%)
# Текущее количество пропущенных значений: 0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as sts


data = pd.read_csv('ECDCCases.csv')
stat = data.describe()
# Поиск выбросов (значений, выходящих за пределы интерквартильного размаха) для числовых признаков
out_val = {} #словарь
for column in data.columns:
    if data[column].dtype != "object":
        IQR = stat[column]["75%"] - stat[column]["25%"]
        lower_bound = stat[column]["25%"] - (1.5 * IQR)
        upper_bound = stat[column]["75%"] + (1.5 * IQR)
        column_out = data[(data[column] < lower_bound) | (data[column] > upper_bound)].shape[0]
        out_val[column] = column_out

# Вывод признаков, содержащих выбросы и количество выбросов для каждого признака
print("Признаки, содержащие выбросы:")
for column, count in out_val.items():
    print(f"{column}: {count} выбросов")

# Поиск стран, для которых количество смертей в день превысило 3000 и количество таких дней
death_countries = data[data["deaths"] > 3000]["countryterritoryCode"].unique()
death_days = data[data["deaths"] > 3000].shape[0]
print(f"Количество стран, где количество смертей в день превысило 3000: {len(death_countries)}")
print(f"Количество дней, когда количество смертей в день превысило 3000: {death_days}")
# Out:
# Признаки, содержащие выбросы:
# day: 0 выбросов
# month: 0 выбросов
# year: 67 выбросов
# cases: 10080 выбросов
# deaths: 10657 выбросов
# popData2019: 6661 выбросов
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000: 8073 выбросов
# Количество стран, где количество смертей в день превысило 3000: 5
# Количество дней, когда количество смертей в день превысило 3000: 11

# %%
import pandas as pd

data = pd.read_csv('ECDCCases.csv')

duplicates = data.duplicated()
print("Количество дубликатов:", sum(duplicates))

data_del = data.drop_duplicates()
print("Количество дубликатов после удаления:", sum(data_del.duplicated()))
# Out:
# Количество дубликатов: 4
# Количество дубликатов после удаления: 0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
from statsmodels.stats import weightstats as stests

data = pd.read_csv('bmi.csv')

# Отбор выборок по регионам
northwest = data[data['region'] == 'northwest']['bmi']
southwest = data[data['region'] == 'southwest']['bmi']

# Проверка выборок на нормальность критерий ШопироУилка
shapiro_test_northwest = stats.shapiro(northwest)
shapiro_test_southwest = stats.shapiro(southwest)
print("Проверка на нормальность Шапиро-Уилка для выборки northwest:", shapiro_test_northwest)
print("Проверка на нормальность Шапиро-Уилка для выборки southwest:", shapiro_test_southwest)

# Проверка выборок на гомогенность дисперсии Критерий Бартлетта
bartlett_test = stats.bartlett(northwest, southwest)
print("Проверка на гомогенность дисперсии Тест Бартлетта:", bartlett_test)

# Проведение t-критерия Стьюдента
t_test = stests.ttest_ind(northwest, southwest, alternative='two-sided')
print("t-критерий Стьюдента:", t_test)
# Out:
# Проверка на нормальность Шапиро-Уилка для выборки northwest: ShapiroResult(statistic=0.9954646825790405, pvalue=0.4655335247516632)
# Проверка на нормальность Шапиро-Уилка для выборки southwest: ShapiroResult(statistic=0.9949268698692322, pvalue=0.3629520535469055)
# Проверка на гомогенность дисперсии Тест Бартлетта: BartlettResult(statistic=3.4000745256463825, pvalue=0.06519347353580048)
# t-критерий Стьюдента: (-3.2844171500398827, 0.001076958496307604, 648.0)

# %%
import scipy.stats

observed = [97, 98, 109, 95, 97, 104]
expected = [100, 100, 100, 100, 100, 100]  # ожидаемое распределение, если кубик равномерный

#Ожидаемое распределение было найдено по формуле математического ожидания
#(среднее значение случаной величины), т.е 1/6*(97+98+109+95+97+104)
chi2, p = scipy.stats.chisquare(observed, expected)

print("Статистика Хи-квадрат:", chi2)
print("p-значение:", p)
# Out:
# Статистика Хи-квадрат: 1.44
# p-значение: 0.9198882077437889

# %%
import pandas as pd
data = pd.DataFrame({'Женат': [89,17,11,43,22,1],
                     'Гражданский брак': [80,22,20,35,6,4],
                     'Не состоит в отношениях': [35,44,35,6,8,22]})

data.index = ['Полный рабочий день','Частичная занятость','Временно не работает',
              'На домохозяйстве','На пенсии','Учёба']

from scipy.stats import chi2_contingency

stat, p, dof, expected = chi2_contingency(data) #dof - число степеней свободы (?)

print("Статистика Хи-квадрат:", stat)
print("p-значение:", p)
# Out:
# Статистика Хи-квадрат: 122.29654948595365
# p-значение: 1.7291616900960234e-21
